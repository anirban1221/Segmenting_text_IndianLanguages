# %% [markdown]
# <a href="https://colab.research.google.com/github/anirban1221/Segmenting_text_IndianLanguages/blob/main/Segmentation_of_hindiText.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

# Paths to your uploaded story files
file_paths = [
    '/content/drive/MyDrive/segmentation_project/story_1.txt',
    '/content/drive/MyDrive/segmentation_project/story_2.txt'
]

# %%
def load_hindi_stories(paths):
    all_text = ""
    for path in paths:
        with open(path, 'r', encoding='utf-8') as file:
            all_text += file.read().strip() + " "
    return all_text

raw_text = load_hindi_stories(file_paths)
print("Sample Text:", raw_text[:500])
# Out:
# Sample Text: श्री गुलेरी जी का जन्म विक्रमी संबत्‌ १६४० में और स्वगवास्त विक्रमी
# संचत्‌ १६६८में हुआ । आप संस्कृत के प्रकांड पंडित थे । आपने कह्दा नियाँ
# गिनती की तीन त्िखीं ।
#
# फिर भी 'डसने कहा था'-आपकी एक उत्कृष्ट कहानों है। यह संबत्‌
# १६७२ की सरस्वती में छुपी थी । इस कहानी का सब से सुन्दर अंश
# उसका अन्तिस दृश्य है । झूत्यु के समय जोवन की विभिन्न घटनाएँ जिस
# रूप में नेन्न-पटक्ष के सामने आ जाती हैं उसका चित्र बहुत ही सुन्दर और
# मनो-वेज्ञानिक ढक्भ से अंकित किया गया है। अनेक इृष्टियों से इस कहानी
# की उत्कृष्ट

# %%
import re

def clean_hindi_text(text):
    text = re.sub(r'\s+', ' ', text)  # remove extra whitespace
    text = re.sub(r'[“”"]', '', text)  # remove special quotes
    text = re.sub(r'[^\u0900-\u097F\s।!?]', '', text)  # keep only Hindi chars and punctuations
    return text.strip()

cleaned_text = clean_hindi_text(raw_text)
print("Cleaned Sample:", cleaned_text[:500])
# Out:
# Cleaned Sample: श्री गुलेरी जी का जन्म विक्रमी संबत् १६४० में और स्वगवास्त विक्रमी संचत् १६६८में हुआ । आप संस्कृत के प्रकांड पंडित थे । आपने कह्दा नियाँ गिनती की तीन त्िखीं । फिर भी डसने कहा थाआपकी एक उत्कृष्ट कहानों है। यह संबत् १६७२ की सरस्वती में छुपी थी । इस कहानी का सब से सुन्दर अंश उसका अन्तिस दृश्य है । झूत्यु के समय जोवन की विभिन्न घटनाएँ जिस रूप में नेन्नपटक्ष के सामने आ जाती हैं उसका चित्र बहुत ही सुन्दर और मनोवेज्ञानिक ढक्भ से अंकित किया गया है। अनेक इृष्टियों से इस कहानी की उत्कृष्टता के कारण ही गुल

# %%
# !pip install stanza

import stanza
stanza.download('hi')
# Out:
# Collecting stanza
#   Downloading stanza-1.10.1-py3-none-any.whl.metadata (13 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (5.29.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from stanza) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from stanza) (3.4.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from stanza) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stanza) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (4.13.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.3.0->stanza)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.3.0->stanza)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.0->stanza) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->stanza) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)
# Downloading stanza-1.10.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 93.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 52.2 MB/s eta 0:00:00
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 31.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, emoji, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed emoji-2.14.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stanza-1.10.1
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: hi (Hindi) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-hi/resolve/v1.10.0/models/default.zip:   0%|          | …
# INFO:stanza:Downloaded file to /root/stanza_resources/hi/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources

# %%
# Load the Hindi NLP pipeline
nlp = stanza.Pipeline('hi', processors='tokenize')

# Apply sentence tokenization
doc = nlp(cleaned_text)

# Extract sentences
sentences = [sentence.text.strip() for sentence in doc.sentences]

# Print the first few sentences
print("Total sentences:", len(sentences))
for i, sentence in enumerate(sentences[:5]):
    print(f"[{i+1}] {sentence}")
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: hi (Hindi):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | hdtb    |
# =======================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Done loading processors!
# Total sentences: 12298
# [1] श्री गुलेरी जी का जन्म विक्रमी संबत् १६४० में और स्वगवास्त विक्रमी संचत् १६६८में हुआ ।
# [2] आप संस्कृत के प्रकांड पंडित थे ।
# [3] आपने कह्दा नियाँ गिनती की तीन त्िखीं ।
# [4] फिर भी डसने कहा थाआपकी एक उत्कृष्ट कहानों है।
# [5] यह संबत् १६७२ की सरस्वती में छुपी थी ।

# %%
import stanza

# Download the Hindi model if not already done
stanza.download('hi')
nlp = stanza.Pipeline('hi')

def extract_pos_words(sentences, target_pos):
    pos_words = set()
    for sent in sentences:
        doc = nlp(sent)
        for word in doc.iter_words():
            if word.upos in target_pos:
                pos_words.add(word.text)
    return pos_words
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: hi (Hindi) ...
# INFO:stanza:File exists: /root/stanza_resources/hi/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: hi (Hindi):
# =============================
# | Processor | Package       |
# -----------------------------
# | tokenize  | hdtb          |
# | pos       | hdtb_charlm   |
# | lemma     | hdtb_nocharlm |
# | depparse  | hdtb_charlm   |
# =============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!

# %%
sentences[2]
# Out:
# 'आपने कह्दा नियाँ गिनती की तीन त्िखीं ।'

# %%
def extract_all_pos_vocab(sentences, target_pos_tags):
    pos_vocab = {tag: set() for tag in target_pos_tags}

    for sent in sentences:
        doc = nlp(sent)
        for word in doc.iter_words():
            if word.upos in target_pos_tags:
                pos_vocab[word.upos].add(word.text)

    return {upos: list(words) for upos, words in pos_vocab.items()}

# %%
target_pos_tags = ['PRON']

pos_vocab = extract_all_pos_vocab(sentences, target_pos_tags)

print("Pronouns:\n", pos_vocab['PRON'])
# Out:
# Pronouns:
#  ['किस', 'हे!नींद', 'अपनीहाँ', 'सदा', 'किसलिये', 'उनकी', 'तुमने', 'सबका', 'हमसे', 'वह', 'हे', 'इसी', 'यहाँनहींनहीं', 'किसका', 'जिनसे', 'प्रेमा!हम', 'तुझसे', 'कहां', 'जिसने', 'पिताजी!', 'जैसा', 'मैं', 'इन्होंने', 'जहाँकीतहाँ', 'नित्य', 'यों', 'इनसे', 'उनके', 'आपसे', 'हमारो', 'सबेरे', '!वह', 'मेरे', 'इन्हीं', 'इससे', '!यह', 'जिसपर', 'किसे', 'आपके', 'हाँहाँ', 'सबही', 'थाजो', 'तुम्हारे', 'जिसे', '!जिनकी', 'जिसका', 'सबको', 'अबकी', 'आपको', 'पाजी!', 'ओह', 'तुम्हारेजेसे', 'भला', 'वेसा', 'कहाँ', 'सुन्दरी!', 'रातभर', 'तू', 'मुझसे', 'तूने', 'अब', 'हमारी', 'अपनीअपनी', 'केसे', 'क्या', 'एकएक', 'जैसे', 'कहाँसेकहाँ', 'इसका', 'सब', 'कया', 'किसी', 'कुछकुछ', 'ना', 'हुश!', 'जिन्हे', 'आपही', 'थेवे', 'कुछु', 'इसे', 'जिसके', 'अपनेअपने', 'थातो', 'सबकी', 'तुमसे', 'आह', 'इसने', 'स्वयं', 'वही', 'उस', 'मानो', 'थाजिस', 'मुझे', 'वेसे', 'हमने', 'आप', 'जहाँ', 'हुजूर!', 'परसों', 'इसीलिए', 'ऐसा', 'सभी', 'किसके', 'कहीं', 'केसा', 'वहाँ', 'ऐसे', 'सहसा', 'उनमें', 'क्', 'वैसे', 'जड़', 'अरे', 'उसका', 'ऐस', 'ऐसी', 'हम', 'ओहो!', 'इसीलिये', 'तभी', 'बेचारा', 'अपनी', 'मुझमें', 'तुममें', 'इनको', 'हाँयह', 'कौन', 'उसके', 'सलाम!', 'इतना!', 'उनको', 'तुझे', 'बेटी!', 'भेया', 'इन्हे', 'अपनाअपना', 'हमारा', 'कहाँकहाँ', 'उन्ही', 'इन्हें', 'तुम्हाराहमारा', 'काक्या', 'कुछनकुछ', 'खुद', '्तो', 'आजकल', 'मु', 'अजी', 'तुमको', 'वैसा', 'जो', 'उन्हें', 'कैसे', 'अरे!बह', 'इसलिये', 'जिस', 'सदेव', 'थाकि', 'जिनमें', 'कितना', 'गयापर', 'जिनका', 'कैसा', 'केसी', 'उनका', 'किससे', 'इहाँ', 'अपना', 'कैसी', 'अभी', 'वे', 'इसके', 'ेउसके', 'जिसमें', 'कहींकहीं', 'कुछ', 'कभी', 'तिनककर', 'हाँ', 'हूँजिस', 'इनकी', 'क्याक्या', 'बेचारे', 'जिन', 'उसको', 'अपने', 'वनलता!', 'मेने', 'जिससे', 'तो', 'कब', 'परस्पर', 'आपने!', 'मै', 'मेंने', 'इसको', 'उसमें', 'तब', 'उसने', 'हमें', 'जिनके', 'इस', 'इसमें', 'देखो', 'किसकी', 'री', 'हाँतो', 'ओर!मेरी', 'थीजब', 'किसने', 'इसकी', 'हमलोग', 'सदेह', 'सचमुच', 'तुम्हारी', 'थीफिर', 'तुम्हारा', 'एक', 'वहे', 'तुम', 'हेफिर', 'तुम्हें', 'तुझको', 'जिसको', 'न!वह', 'मैंने', 'जेसी', 'वहीं', 'इनमें', 'यहीं', 'क्यों', 'दूसरे', 'हमारे', 'कई', 'मुझ', 'सबके', 'तिस', 'आप?', 'सो', 'तुम्हीं', 'कितनों', 'क्यो', 'दूसरीजो', 'ये', 'यहाँ', 'हूँतू', 'जिन्होंने', 'हमको', 'तुम्हार', 'उन्हीं', 'अभीअभी', 'आपस', 'उसे', 'भगवन्!', 'इनका', 'मेरा', 'जिसकी', 'जेसेतेसे', 'मुझको', 'जिधर', 'आपकी', 'मेरीउसकी', 'नहींनहीं', 'जेसे', 'यही', 'मन्न्!यह', 'उसी', 'कितने', 'नाहक', 'मेरी', 'किसको', 'ऊषाकाल!', 'कुछओर', 'मुझी', 'छिः', 'सबने', 'जिन्हें', 'उसकी', 'उन', '!घर', 'उन्होंने', 'इनके', 'जेसा', 'कोन', 'तेरी', 'काहे', '!जब', 'आपने', 'हुजूर', 'कोई', 'हूँमेरे', 'किसलिए', 'उनसे', 'हमारातुम्हारा', 'यह', '!इतना', 'धीरेधीरे', 'जब', 'आपका', 'चलो', 'जिनकी', 'हा', 'तेरा', 'में', 'बह', 'वहि', 'इसलिए', 'आह!', 'तेरे', 'मानों', 'उससे', 'तुझ', 'किधर']

# %%
def segment_with_pos_aware_rules(sentences, pronouns):
    segments = []
    current_segment = []

    for sentence in sentences:
        words = sentence.strip().split()

        # Check if any word is a pronoun, conjunction, or connective
        if any(word in pronouns for word in words):
            current_segment.append(sentence)
        else:
            if current_segment:
                segments.append(" ".join(current_segment))
            current_segment = [sentence]

    # Final append
    if current_segment:
        segments.append(" ".join(current_segment))

    return segments

# %%
# Step 1: Get POS vocab
target_pos_tags = ['PRON']
pos_vocab = extract_all_pos_vocab(sentences, target_pos_tags)

# Step 2: Extract specific lists
pronouns = pos_vocab['PRON']


# Step 3: Segment
segments = segment_with_pos_aware_rules(sentences, pronouns)

# View segmented output
# for i, seg in enumerate(segments, 1):
#     print(f"[Segment {i}]: {seg}\n")

# %%
from sentence_transformers import SentenceTransformer

# Load multilingual sentence transformer
model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')

# Generate embeddings for each segment
segment_embeddings = model.encode(segments, convert_to_tensor=True)

# Optional: View embeddings
print("Number of segments:", len(segments))
print("Embedding shape for one segment:", segment_embeddings[0].shape)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Number of segments: 2194
# Embedding shape for one segment: torch.Size([384])

# %%
# !pip install python-louvain

# %%
# import networkx as nx
# from sklearn.metrics.pairwise import cosine_similarity
# from community import community_louvain  # install via: !pip install python-louvain
# import numpy as np

# # Convert list of embeddings to NumPy array
# embedding_matrix = np.array(segment_embeddings)

# # Compute cosine similarity matrix
# similarity_matrix = cosine_similarity(embedding_matrix)

# # Build similarity graph
# G = nx.Graph()
# threshold = 0.60  # You can tune this later

# for i in range(len(sentences)):
#     for j in range(i + 1, len(sentences)):
#         sim = similarity_matrix[i][j]
#         if sim > threshold:
#             G.add_edge(i, j, weight=sim)

# %%
import os

save_dir = '/content/drive/MyDrive/segmentation_project'
os.makedirs(save_dir, exist_ok=True)

# %%
with open(os.path.join(save_dir, 'sentences.txt'), 'w', encoding='utf-8') as f:
    for sent in sentences:
        f.write(sent.strip() + '\n')

# Save segments (rule-based or clustered)
with open(os.path.join(save_dir, 'segments.txt'), 'w', encoding='utf-8') as f:
    for seg in segments:
        f.write(seg.strip() + '\n')

# %%
import numpy as np

embedding_matrix = segment_embeddings.cpu().numpy()
np.save(os.path.join(save_dir, 'segment_embeddings.npy'), embedding_matrix)

# %%
import numpy as np

base_path = '/content/drive/MyDrive/segmentation_project'

# Load sentences
with open(f'{base_path}/sentences.txt', 'r', encoding='utf-8') as f:
    sentences = [line.strip() for line in f.readlines()]

# Load segments
with open(f'{base_path}/segments.txt', 'r', encoding='utf-8') as f:
    segments = [line.strip() for line in f.readlines()]

# Load segment embeddings
segment_embeddings = np.load(f'{base_path}/segment_embeddings.npy')

# %%
import numpy as np
import networkx as nx
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import SpectralClustering
import matplotlib.pyplot as plt

# Step 1: Build Similarity Matrix
similarity_matrix = cosine_similarity(segment_embeddings)

# Step 2: Optional — Visualize similarity heatmap
# import seaborn as sns
# plt.figure(figsize=(10, 8))
# sns.heatmap(similarity_matrix, cmap='viridis')
# plt.title("Cosine Similarity Matrix of Segment Embeddings")
# plt.show()

# Step 3: Convert similarity matrix to graph
G = nx.Graph()
num_sentences = len(similarity_matrix)

# Add edges for sentence pairs with similarity > threshold
threshold = 0.75  # Tune this!
for i in range(num_sentences):
    for j in range(i + 1, num_sentences):
        sim = similarity_matrix[i][j]
        if sim > threshold:
            G.add_edge(i, j, weight=sim)

# %%
import community as community_louvain
import networkx as nx

# Assuming G is the similarity graph
partition = community_louvain.best_partition(G)

# Group sentences by their assigned community
from collections import defaultdict

community_segments = defaultdict(list)
for node, comm_id in partition.items():
    community_segments[comm_id].append(sentences[node])
# Sort segments by sentence order
for comm_id in community_segments:
    community_segments[comm_id].sort(key=lambda s: sentences.index(s))

# Final segmented output
final_segments = [' '.join(community_segments[k]) for k in sorted(community_segments)]

# %%
for i, segment in enumerate(final_segments):
    print(f"Segment {i+1}: {segment}\n")
# Out:
# Segment 1: फिर भी डसने कहा थाआपकी एक उत्कृष्ट कहानों है। युवक ओर युवती ने मस्तक झुकाकर महाराजा को अभिवादन किया।
#
# Segment 2: यह संबत् १६७२ की सरस्वती में छुपी थी । इस पर लड़की कुछ आँखे चढह़ाकर धत! कहकर दौड़ गई और लड़का मु ह देखता रह गया  दूसरेतीसरे दिन सब्जीवाले के यहाँ या दूधवाले के यहाँ अकस्मात् दोनों मिल जाते । मिला  एक दिन उसने कहद्दा था   ४७ जब फिर लड़के ने वैसे ही हँसी में चिढ़ाने के लिये पूछा तब लड़की लड़के की संभावना के विरुद्ध बोलीहाँ हो गई । लड़की भाग गईं  लड़के ने घर की राह ली । गनीम कहीं दिखाता नहीं घंटे दो घंटे में कान के परदे फाइनेवाले धमाके के साथ सारी खंदक हिला जाती है और सौसो गज घरती॥उछुल पड़ती है। परसों रिलीफ़ आ जायेगी ओर फिर सात दिन की छुट्टी । नहीं तो सोधे बलिन पहुँच जाते। क्यों  सूबेदार हजारा सिंह ने मुह्करा कर कहालड़ाई के मामते जमादार या नायक के चलाये नहीं प्चलते । बड़े अफसर दूर की सोचते हैं  तीन सो मील का सामना है एक तरफ बढ़ गये तो क्या होगा १ सूबेदार जी सच हे लहना सिंह बोलापर करें क्या! हड्डियों में जो जाड़ा धस गया है। करो जर्मनी के बादशाह का तपंण !? देसदेस की चाल है। आज तक में उसे समझा न सका कि सिख तमाकू नहीं पीते  वह सिगरेट देने में हु० करती है ओठों में लगाना चाहती है और में पीछे दृटता हूँ तो समझती है कि राजा बुरा मान गया अब मेरे मुल्क के लिये लड़ेगा नहीं  अच्छा अब बोधसिंह कैसा है १? ! तुम यहाँ दस आदमी छोड़ उसने कद्दा था   ६६१ कर सबको साथ ले उनसे जा मिलो । लड़ाई ख़त्म होने पर । और मुझे पीने को सिगरेट दिया है । में लप्टन साइबर की ख़बर लेता हूँ ? लहना ने पतलून की जेबों की तलाशी नहीं ली थी। थोड़े से मिनटों में वे अचानक श्रावाज़ आईबाह शुरुभी की फ़तह ! बाह गुरुती का खालसा ? रोतीरती सूबेदारनी श्रोबरी में चली गई। ननन। नो बजने के बाद सूर्य का उदय हुआ है। छोटासा बजरा अपनी मस्तानी चाल से जाहनवी के शीतल जल में सन््तरण कर रहा है। दूर खड़ा हुआ गाँव का एक बालक उसे माँगते देखकर चकित हो गया। वह बोला  बाबू जी यह पंचवटी के अघोरी हैं
#
# Segment 17: इतने भें खाई के भ्लुद्द से आवाज़ झाईसूबेदार हजारासिंह  कौन ! लप्टन साइब ? हुकुम हुज्लर  कहकर सूबेदार तन कर फ़ोजी सलाम करके सामने हुआ।
#
# Segment 18: जो हुकस ?! चुपचाप सब तेयार हो गए । बोधा सी कंबल्ल उतारकर खलने लगा।
#
# Segment 19: लद्दनासिंद ने जाँचना चाहा  लपटन साहब पाँच वष से उसकी रेजिमेंट में थे । मालिन किंकर्तग्यविमूढ़ होकर मधूकवृक्ष के नीचे बेठ गई। कहकर में सोच रहा था कि कहीं मुझे खरीदना न पड़े। उसकी आँखों से ज्वाला निकल रही थी।
#
# Segment 20: क्यों क्या यद्द देश पसन्द नहीं ९? फिर वही सुन्दरी वनदेवी की तरह मन्थर गति से उसी झरने के समीप आई जहाँ पुरुरवा बेठे हैं।
#
# Segment 21: फूल छूने से कुम्हिलाते हें उनमें कीट होते हैं उसे में पहनकर क्या करूँगी। युवक ने कहा  फूलों की माला से तो उर्वशी को मूर्च्छा नहीं आ सकती।
#
# Segment 22: उसे बड़ेबड़े सींग  दो दो फुट के तो हॉगे ? पत्ता तक न खुड़के  देर मत करो ? ऐसी तैसी हुकुम की  मेरा हुकुमजमादार लहनासिंद जो इस वक्त यहाँ सबसे बड़ा अफ़सर है उतका हुकुम है। घमाके के साथ साहब के हाथ से दियासलाई गिर पड़ी  लइनासिंह ने एक कुंदा साहब की गदन पर मारा और साहब आह  माई गाड !?? कहते हुए चित्त हो गए  लहनारिंह ने तीनों गोले बीनकर खंदक के बाहर फेंके और साहब को घस्तीटकर सिगड़ी के  पास लियायथा जेबों की तलाशी ली  तीनचार लिफ़ाफ़े और एक  डायरी निकालकर उन्हें अपनी जेब के हवाले किया  साहब की मुच्छां दटी  लदनाविंद हँसकर बोलाक्यों ल्पटन साइन ! मिजाज़ कैसा है !
#
# Segment 23: ज़रा तो आँख लगने दी द्ोती १? क् ह ४ होश में आओ  क़यासत आई है और लपटन साहब की वर्दी पहन कर आई है ? जग्गेया नटखट था। उसके हृदय में उद्गेश ओर शरीर में कम्प था। उसने पूछा  तब तुम पढ़ सकोगे केसे? दिन अभी छप्टेडेढ़धण्टे बाकी था। अधरों में कुंचित हँसी आँखों में प्रकाश भरे प्रज्ञासारथि ने मुझे देखते हुए कहा  आज मेरी इच्छा थी कि आपसे भेंट हो। कहा  हाँ राजकुमार! यह मेरा शेशव सहचर है।
#
# Segment 24: सूबेदार कीचड़ में चक्कर काटते फिरेगे ओर यहाँ खाई पर घावा होगा  उधर उन पर खुले में धावा होगा  उठो एक काम करो । एक हजार।
#
# Segment 25: यह सीखा कि मुसलमान खामसामा भूक्तियों पर जल चढ़ाते हैं श्रौर लपठन साहब खोते पर चढ़ते हैं  पर सह ६४   कहानी अवेश तो कहो ऐसी साफ़ उद्ं कहाँ से सीख आए  हमारे लपठन साहब तो बिना ड्लैम्? के पांच लफ़्ज़ भी नहीं बोला करते थे । यह केसी लीला थी!
#
#
# Segment 45: किशोर मूल्य माँगने लगा। उसने गाड़ीवान से चलने के लिए कहा। मैकू हँस पड़ा।
#
# Segment 46: रानी की आज्ञा थी। दोनों ने अपनी रुकावट हटा ली। अब मुझे इनाम मिलना चाहिए।
#
# Segment 47: नवीन राजपुत्र को मृगया की शिक्षा के लिए लक्ष्य साधने के लिए वही नगरोपकण्ठ का वन स्थिर हुआ। कोकिला भी कूककुक कर आम की डालों को हिलाये देती है। गुल से भी कह दो।
#
# Segment 48: उसकी निश्चेष्ट आँखें मोन भाषा में जेसे माँमाँ कह रही थीं। सूर्य बहुत ऊपर आ चुके थे मुझे प्यास लगी थी। युवती ने हाथ जोड़कर कहा  आप लोग दुःख मत दीजिये। उन नरपिशाचों ने एक को भी न छोड़ा! सबकी हत्या की। मेरे विचार से यह प्राचीन आर्यप्रथा भी थी! में गार्हस्थ्यजीवन से परिचित होना चाहता हूँ। तुम्हारी यह छटा! युगल जोड़ी की मनोहर लीला दर्शनीय है।
#
# Segment 49: में मुस्करा कर रह गया। माँ के मर जाने पर अपने शराबी ओर अकर्मण्य पिता के साथ वह कंजरों के हाथ लगी।
#
# Segment 50: एक मनुष्य पानी पी रहा था उससे पूछने पर मालूम हुआ कि गाँव में एक भारी दुर्घटना हो गयी है। दोपहर को धुरहट्टा खेलने के समय नशे में रहने के कारण कुछ लोगों में दंगा हो गया।
#
# Segment 51: रात को उसी के मकान पर डाका पड़ा। एक लड़की को हवा लगी हे यहीं का कोई आसेब है।
#
# Segment 52: उनका उपयोग करने के लिए माला बनाई। पुरुरवा ने कहा  तुम्हें माला पहनाने का क्या अधिकार था?
#
# Segment 53: अशोक पूतसलिला भागीरथी के तट पर चन्द्रालोक में महाराज चक्रवर्ती अशोक टहल रहे हैं। सवेरा हो गया था।
#
# Segment 54: उसे इसका कुछ भी ध्यान नहीं है कि कोई व्याप्र उसकी ओर अलक्षित होकर बाण चला रहा है। युवक उठा और उसी कुंज की ओर चला।
#
# Segment 55: उसका सिर स्वयं अवनत हो गया। रमणी स्थिर होकर खड़ी थी।
#
# Segment 56: किन्तु वह शान्ति देर तक न रही क्योंकि एक दोड़ता हुआ मृगशावक कुनाल की गोद में आ गिरा जिससे उसके ध्यान में विघ्न हुआ ओर वह खड़ा हो गया। धर्मरक्षिता  नाथ इस स्थान पर यदि सुख न मिला तो में समझूगी कि संसार में भी कहीं सुख नहीं हे।
#
# Segment 57: कुनाल ने उस मृगशावक को देखकर समझा कि कोई व्याप्र भी इसके पीछे आता ही होगा। नगरनिवासी प्रायः उद्विग्न हो रहे हैं।
#
# Segment 58: मधुर पवन भी उस भूमि में उसी प्रकार चलने लगा। में आपके मित्रों को यहाँ देखकर प्रसन्न ही होऊँगा।
#
# Segment 59: कुटी के बाहर एक पत्थर पर अधेड़ मनुष्य बेठा हुआ हे। लेला को विश्वास था कि सूरत बम्बई काश्मीर वह चाहे कहीं हो में उसे लिवाकर चलूँगा ही।
#
# Segment 60: अब सब सेनिक धन खोजने लगे। बेला अपने परिचित पलाश के नीचे बेठकर गाने लगी  चीन्हत नाहीं बदल गये नेना ऐसा मालूम होता था कि सचमुच गोली उस अन्धकार में अपरिचित की तरह मुँह फिराकर चला जा रहा है। बेला की मनोवेदना को पहचानने की क्षमता उसने खो दी है।
#
# Segment 61: महाराज ने शासक की ओर देखा। क्या उस दिन तुमने इसी कुकर्म के लिये राजमुद्रा छिपा ली थी?
#
# Segment 62: कुनाल ने आगे बढ़ घुटने टेक दिये और कहा  क्षमा। ताल पर नाचती हुई लाललाल किरनें वृक्षों के अन्तराल से बड़ी सुहावनी लगती थीं।
#
# Segment 63: आज के प्रभात में कुछ अधिक सरसता थी। अन्धकार के साम्राज्य में तृण लता व॒ुक्ष सचराचर कम्पित हो रहे थे। वह सकुच कर खड़ी हो रही।
#
# Segment 64: वहाँ कभी एक सराय भी थी अब उसका ध्वंस बच रहा था। अपने को प्रमाणित करने की चेष्टा उसमें थी ही नहीं।
#
# Segment 65: रामेश्वर एक सफल कदम्ब है जिसके ऊपर मालती की लता अपनी सेकड़ों उलझनों से आनन्द की छाया ओर आलिंगन का स्नेहसुरभि ढाल रही हे। श्रीनाथजी! मेरे ध्यान में आपके आने की सम्भावना न थी।
#
# Segment 66: रामेश्वर के हाथ के ऊपर मालती की पीली हथेली जिसके ऊपर जलधारा पड़ रही थी। उसके बालबच्चे सब साथ हैं। पुरुरवा ने कहा  उर्वशी! आज तो अद्भुत रूप हे।
#
# Segment 67: इनके लिए सफेद नीला सुर्ख का श्रेणीविभाग कर लिया गया है। यहाँ वेसा नहीं मिलता।
#
# Segment 68: बेचारा कभी न सोचेगा कि कोई गम्भीर विचार करते हुए जीवन की किसी कठिनाई से टकराते रहने से भी पीड़ा हो सकती है। में कुछ न समझ सका। अब लेला ने मुस्कराते हुए बेग में से वही पत्र निकाला।
#
# Segment 69: तो भी में हल्कीसी तन्द्रा केवल तबीयत बनाने के लिए ले ही लेता हूँ। में उठ खड़ा हुआ दालान में आकर देखता हूँतो एक बीस बरस के युवक के साथ लेला।
#
# Segment 70: उनका विश्वास था कि चंदा का तट किसी दिन तथागत के पवित्र चरण चिहन से अंकित हुआ था वे आज भी उन्हें खोजते थे। अपनी मूर्खतापूर्ण करनी से मेरा ही दम घुटने लगा।
#
# Segment 71: प्रज्ञासारथि ने कहा। खा ले पी ले मोज मना ले मोह नींद ते क्यों जागे?
#
# Segment 72: भाई तुम बड़े चतुर हो। ओर रामेश्वर से भेंट करा दूँगा।
#
# Segment 73: सुरमीली आँखों में कितना नशा है ओर अपने मादक उपकरणों से भी रामेश्वर को अपनी ओर आकर्षित करने में वह असमर्थ है। दिनभर काम करने के बाद अब तो छुट्टी मिली हे बदन ठण्डा कर रही हूँ।
#
# Segment 74: तो क्या वह मुझ पर कुछ सन्देह करता है? रामेश्वर ने पूछा  क्या है रे कमलो?
#
# Segment 75: मेंने बाँसुरी बजाना बन्द किया और ठीक विश्रामकाल में ही मैंने देखा कि प्रज्ञासारथि सामने खड़े हैं। मेंने समझा यह भी कोई छलना होगी।
#
# Segment 76: मेरे सिंघली मित्र ने हँस कर कहा  अभी तो एक महीने यहाँ में अवश्य रहूँगा। भिक्षुओं के रहने के लिए तो संघाराम का भाग अलग हे ही ओर उसमें जो कमरे अभी अधूरे हें उन्हें शीघ्र ही पूरा कराकर तब में जाऊँगा ओर अपने संघ से में इसकी पक्की लिखा पढ़ी कर रहा हूँ कि आप पाठशाला के आजीवन अवेतनिक प्रधानाध्यक्ष रहेंगे ओर उसमें किसी को हस्तक्षेप करने का अधिकार न होगा।
#
# Segment 77: उसने पूछा  तो कब कहाँ चलना होगा? जब खोजने पर उसकी स्त्री नहीं मिली तो उसने चिललाकर कहा  यह अन्याय इस राज्य में नहीं होना चाहिए। मेरी योगिनी कह रही हे।
#
# Segment 78: ओर फिर धीरेधीरे अनिच्छापूर्वक पाठशाला की ओर लोटा। बेला के इस कथन में भयानक व्यंग था।
#
# Segment 79: ओर में? में कह चुका था इसलिए दूसरे दिन लेला से भेंट करने पहुँचा। गाँव के लोग उसके गीतों के लिए कंजरों को शीघ्र हटाने का उद्योग नहीं करते!
#
# Segment 80: में ठिठककर सुनने लगा  रमणीकण्ठ की मधुर ध्वनि! मैंने देखा कि लेला की भी आँखें उस संगीत के नशे में मतवाली हो चली हैं। मेंने एक क्षण के लिए अपने को कोसा इतने सुन्दर संसार में कलह की ज्वाला जला कर में तमाशा देखने चला था। उन्होंने मुझे पुकारा  श्रीनाथजी! मेंने हँसने की चेष्टा करते हुए कहा  कहिए!
#
# Segment 81: जेसे उसने अपने हृदय का समस्त बल आनेवाली घटनाओं का सामना करने के लिए एकत्र कर लिया हो क्योंकि मालती जलपान लिये आ ही रही थी। मालती खड़ी सुनती रही ओर में सूरन के लड्डू खाता रहा।
#
# Segment 82: उसने मालती से पचास के नोट देने के लिए कहा। मालती अपने पति के व्यवसाय को जानती थी उसने तुरन्त नोट दे दिये।
#
# Segment 83: में जागता था  सोता था। यदि रामेश्वर मालती और अपने बालबच्चों की चिन्ता छोड़कर लेला को ही देखता तभीकिन्तु वेसा हो केसे सकता है।
#
# Segment 84: क्षणभर के लिए जेसे दोनों चोंक उठते। सब लोग उस पर प्रसन्न होकर पैसोंरुपयों की बोछार करने लगे। गर्वितहृदय को एकाधिपत्य से वंचित होने का अनुभव होने लगा।
#
# Segment 85: उसे जेसे सायंकाल में एक हलकासा उन््माद हो जाता। गढ़ के चौक में जब उसका गाना जमता तो दूसरा काम करते हुए अन्यमनस्कता की आड़ में मनोयोग से और कनखियों से ठाकुर उसे देख लिया करते।
#
# Segment 86: पपिहा करत पुकार काहु को आगम जानी॥ कहूँ लोल लतिका पर निरतत मधुकरगन जुरि। क्या ये प्यार करने के योग्य नहीं हें?
#
# Segment 87: ठाकुर ने उसे देखकर पूछा  क्या हे? सरकार! कुछ कहना है। यह छोकरी इस गाँव से जाना नहीं चाहती। उधर पुलिस तंग कर रही है। जाना नहीं चाहती क्यों?
#
# Segment 88: उस्तादों से गाना सीखा है। ठाकुर साहब की उमंग की रातें वहीं कटती हैं।
#
# Segment 89: चन्द्रोदय हुआ। पुरुरवा ने आग्रह से एक मेषशावक को गोद में बेठा लिया।
#
# Segment 90: अब सुन्दरी के हाथ में एक छोटीसी वीणा भी है। रमणी ने कहा  चित्त चिर चंचल है।
#
# Segment 91: वीणा बजने लगी। उनका वह सब सुन्दर लीलामय भाव तिरोहित हो चला।
#
# Segment 92: रूप सुधा सरवर की सफरी बसत नहीं दिनरात प्यासे ही तउ रहत नेन तुम यह केसी है बात? शैल शूंग को परसि मेघ मण्डली सुहावे  करि गम्भीर निनाद नवीन मूंग सुनावे।
#
# Segment 93: प्रमोद भरी ये सुप्िनी वृन्द भरी मकरन्द लगी ललचान। बढ़ी कान्ति जग बीच युवा ह॒वे प्रकृति दिखानी खिले कुसुम के मिस मानहूँ सुन्दरि मुसुक्यानी।
#
# Segment 94: चितोन लगी निज पीतम ओर रहयो नहिं धीर छुटयो सकुचान। मनोहर गुफा पहाड़ी में प्रेमी की तरह हृदय खोले बेठी हे।
#
# Segment 95: वियोगिनी पीत कपोल सों चन्द्रकला अब सेस लगी दरसान। द्वाक्षा की लता उसे घेरे है।
#
# Segment 96: प्यारी ऊषा के सुकेश कलाप में सोहत भूषण केंधों मनी को। के रति कामिनी को भरयो लाल सु हाला ते प्यारा है नीलमनी को। पुरुरवा एकटक उस पार्वतीय पावस की शोभा देख रहे हें।
#
# Segment 97: प्राची दिशा बरबाल के भाल में लाग्यो गुलाल को मंगल टीको॥ खेलि के होरी निशंक निशा ते मयंक कढ्यो हुलसाइके जी को। हृदय कुछ अनमना है।
#
# Segment 98: सुखद समीर अपनी मन्थर गति से गिरिशूंगों तथा वृक्षों पर पड़ती हुई भुवनभास्कर की किरणों को विचलित करने का उद्योग कर रहा है। ओर उर्वशी की कोकिल कण्ठध्वनि भी उससे मिलकर अपूर्व समाँ बाँध रही हे।
#
# Segment 99: कुसुमित डालों पर बेठे हुए पक्षीगण अपने मूदुल कण्ठ से प्रभात का यशोगान कर रहे हें। हियो यह भयो नदी बरसाती उमड़ि पडयो कुलकूल छोडिक़े भूले सबे संघाती।
#
# Segment 100: नवयोवन नवीन समागम में पुलकित भोग में डूबे हुए विलास सागर में तेरते हुए एकदूसरे के सहारे झरना के तट पर बेठे हुए पुरुरवा और उर्वशी हँसती हुई सृष्टि का आनन्द ले रहे हें। निसदिन बेग बढ़यो बहिबे को होंस न हिये समाती लपटि तरुन ते पतित कियो वह विकल भयो लगि छाती।
#
# Segment 101: उर्वशी के सामने चुने हुए फूलों का ढेर है। पायो सुख न मलिनता बाढ़ी वही दिवस वहि राती।
#
# Segment 102: पुरुरवा उसे उठाकर देते हैं वह उन फूलों से एक सुन्दर माला गँथ रही है। भवसागर के प्रबल लहर में धारा नितहि समाती।

# %%
# !pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Collecting sentence-transformers
#   Downloading sentence_transformers-4.0.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.50.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.30.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.1.31)
# Downloading sentence_transformers-4.0.2-py3-none-any.whl (340 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.6/340.6 kB 12.1 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence-transformers
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 3.4.1
#     Uninstalling sentence-transformers-3.4.1:
#       Successfully uninstalled sentence-transformers-3.4.1
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 sentence-transformers-4.0.2

# %%
import random
from itertools import combinations, product

def create_contrastive_pairs(segments, num_negative_samples_per_segment=2):
    positive_pairs = []
    negative_pairs = []

    # Positive pairs: from same segment
    for segment in segments:
        sentences = segment.strip().split("।")  # Hindi sentence delimiter
        sentences = [s.strip() for s in sentences if s.strip()]
        if len(sentences) >= 2:
            positive_pairs.extend(list(combinations(sentences, 2)))

    # Negative pairs: from different segments
    for i, seg1 in enumerate(segments):
        sents1 = seg1.strip().split("।")
        sents1 = [s.strip() for s in sents1 if s.strip()]
        if not sents1: continue

        for _ in range(num_negative_samples_per_segment):
            j = random.randint(0, len(segments) - 1)
            while j == i:
                j = random.randint(0, len(segments) - 1)
            sents2 = segments[j].strip().split("।")
            sents2 = [s.strip() for s in sents2 if s.strip()]
            if not sents2: continue

            # Randomly pick one sentence from each segment
            sent1 = random.choice(sents1)
            sent2 = random.choice(sents2)
            negative_pairs.append((sent1, sent2))

    return positive_pairs, negative_pairs

# %%
positive_pairs, negative_pairs = create_contrastive_pairs(segments, num_negative_samples_per_segment=3)

print(" Sample Positive Pair:\n", positive_pairs[0])
print(" Sample Negative Pair:\n", negative_pairs[0])
print(f"\nTotal Positive Pairs: {len(positive_pairs)}")
print(f"Total Negative Pairs: {len(negative_pairs)}")
# Out:
#  Sample Positive Pair:
#  ('श्री गुलेरी जी का जन्म विक्रमी संबत् १६४० में और स्वगवास्त विक्रमी संचत् १६६८में हुआ', 'आप संस्कृत के प्रकांड पंडित थे')
#  Sample Negative Pair:
#  ('कब १? कलदेखते नहीं यह रेशम से कढा हुआ सालू', 'शिलाखण्ड के नीचे ही पगडण्डी थी')
#
# Total Positive Pairs: 52997
# Total Negative Pairs: 6582

# %%
from torch.utils.data import Dataset
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer

class ContrastivePairsDataset(Dataset):
    def __init__(self, positive_pairs, negative_pairs, model_name='sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2'):
        self.pairs = positive_pairs + negative_pairs
        self.labels = [1]*len(positive_pairs) + [0]*len(negative_pairs)

        self.tokenizer = AutoTokenizer.from_pretrained(model_name)

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        sent1, sent2 = self.pairs[idx]
        label = self.labels[idx]

        encoded = self.tokenizer(sent1, sent2, padding='max_length', truncation=True, return_tensors='pt', max_length=256)

        return {
            'input_ids': encoded['input_ids'].squeeze(0),
            'attention_mask': encoded['attention_mask'].squeeze(0),
            'label': label
        }

# %%
from torch.utils.data import DataLoader, random_split

# Initialize dataset
dataset = ContrastivePairsDataset(positive_pairs, negative_pairs)

# Optionally split into train/val
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# Dataloaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
import torch
import torch.nn as nn
from transformers import AutoModel

class SiameseContrastiveModel(nn.Module):
    def __init__(self, model_name='sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2'):
        super(SiameseContrastiveModel, self).__init__()
        self.encoder = AutoModel.from_pretrained(model_name)

    def forward(self, input_ids1, attention_mask1, input_ids2, attention_mask2):
        output1 = self.encoder(input_ids=input_ids1, attention_mask=attention_mask1)
        output2 = self.encoder(input_ids=input_ids2, attention_mask=attention_mask2)

        # Use [CLS] token embeddings
        emb1 = output1.last_hidden_state[:, 0, :]
        emb2 = output2.last_hidden_state[:, 0, :]

        return emb1, emb2

# %%
from torch.nn import CosineEmbeddingLoss
import torch.optim as optim
from tqdm import tqdm

def train(model, train_loader, val_loader, epochs=5, lr=2e-5, device='cuda'):
    model.to(device)
    optimizer = optim.AdamW(model.parameters(), lr=lr)
    criterion = CosineEmbeddingLoss()

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for batch in tqdm(train_loader, desc=f"Training Epoch {epoch+1}"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            label = batch['label'].to(device)

            # Split into two sentence sets
            input_ids1 = input_ids[:, 0:128]
            attention_mask1 = attention_mask[:, 0:128]
            input_ids2 = input_ids[:, 128:]
            attention_mask2 = attention_mask[:, 128:]

            optimizer.zero_grad()
            emb1, emb2 = model(input_ids1, attention_mask1, input_ids2, attention_mask2)

            # Convert labels: 1 -> 1.0, 0 -> -1.0
            targets = 2 * label.float() - 1
            loss = criterion(emb1, emb2, targets)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        train_loss=total_loss/len(train_loader)
        model.eval()
        total_val_loss = 0
        with torch.no_grad():
            for batch in tqdm(val_loader, desc=f"Validating Epoch {epoch+1}"):
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                label = batch['label'].to(device)

                # Split into two sentence sets for contrastive learning
                input_ids1 = input_ids[:, 0:128]
                attention_mask1 = attention_mask[:, 0:128]
                input_ids2 = input_ids[:, 128:]
                attention_mask2 = attention_mask[:, 128:]

                emb1, emb2 = model(input_ids1, attention_mask1, input_ids2, attention_mask2)

                # Convert labels: 1 -> 1.0, 0 -> -1.0
                targets = 2 * label.float() - 1
                val_loss = criterion(emb1, emb2, targets)
                total_val_loss += val_loss.item()

        val_loss = total_val_loss / len(val_loader)

        # Print training and validation loss for this epoch
        print(f"Epoch {epoch+1}/{epochs} — Train Loss: {train_loss:.4f} — Val Loss: {val_loss:.4f}")

# %%
model = SiameseContrastiveModel()
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]

# %%
# Step 2: Start training
train(model, train_loader, val_loader, epochs=5, lr=2e-5, device='cuda')
# Out:
# Training Epoch 1: 100%|██████████| 1490/1490 [10:31<00:00,  2.36it/s]
# Validating Epoch 1: 100%|██████████| 373/373 [00:50<00:00,  7.39it/s]
# Epoch 1/5 — Train Loss: 0.1124 — Val Loss: 0.1118
# Training Epoch 2: 100%|██████████| 1490/1490 [10:33<00:00,  2.35it/s]
# Validating Epoch 2: 100%|██████████| 373/373 [00:50<00:00,  7.39it/s]
# Epoch 2/5 — Train Loss: 0.1104 — Val Loss: 0.1118
# Training Epoch 3: 100%|██████████| 1490/1490 [10:32<00:00,  2.35it/s]
# Validating Epoch 3: 100%|██████████| 373/373 [00:50<00:00,  7.38it/s]
# Epoch 3/5 — Train Loss: 0.1103 — Val Loss: 0.1118
# Training Epoch 4: 100%|██████████| 1490/1490 [10:33<00:00,  2.35it/s]
# Validating Epoch 4: 100%|██████████| 373/373 [00:50<00:00,  7.37it/s]
# Epoch 4/5 — Train Loss: 0.1102 — Val Loss: 0.1118
# Training Epoch 5: 100%|██████████| 1490/1490 [10:32<00:00,  2.35it/s]
# Validating Epoch 5: 100%|██████████| 373/373 [00:50<00:00,  7.42it/s]
# Epoch 5/5 — Train Loss: 0.1102 — Val Loss: 0.1118

# %%
model_save_path = "/content/drive/MyDrive/segmentation_project/segmenter_model_new.pt"
torch.save(model.state_dict(), model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to /content/drive/MyDrive/segmentation_project/segmenter_model_new.pt
